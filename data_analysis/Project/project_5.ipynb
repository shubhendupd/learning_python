# %% [markdown]
# London Housing dataset( Bigdata analysis)
#
# This dataset is primarily centered around  the housing market of London. It contains a lot of additional  relevant data.
# - Monthly average house prices
# - Yearly number of houses sold
# - Monthly number of crimes committed
#
# the data used here is from year 1995 to 2019 of each different area.

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\Shubhendu Prasad\Documents\Programming\Programming\python_for_ai\learning_python\data_analysis\dataset_file\5. London Housing Data.csv')

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 13544           NaN
# 13545           NaN
# 13546           NaN
# 13547           NaN
# 13548           NaN
#
# [13549 rows x 6 columns]

# %% [markdown]
# 1.
# df.count()
# df.isnull().sum()

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %% [markdown]
# 2. import seaborn as sns
# import mathplotlib.pyplot as plt
# sns.heatmap(df.isnull())
# plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# A) convert the datatype of date column to date-time format.

# %%
data.dtypes
# Out:
# date             datetime64[us]
# area                        str
# average_price             int64
# code                        str
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
data.date = pd.to_datetime(data.date)

# %% [markdown]
# B 1)  Add a new column  year  in the dataframe which contains years only

# %%
data['year'] = data.date.dt.year

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# 2               NaN  1995
# 3               NaN  1995
# 4               NaN  1995
# ...             ...   ...
# 13544           NaN  2019
# 13545           NaN  2019
# 13546           NaN  2019
# 13547           NaN  2019
# 13548           NaN  2020
#
# [13549 rows x 7 columns]

# %% [markdown]
# B 2) Add a new column "month" as 2nd column in the dataframe, which contains month only.

# %%
data.insert(1,'month', data.date.dt.month)

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 13544           NaN
# 13545           NaN
# 13546           NaN
# 13547           NaN
# 13548           NaN
#
# [13549 rows x 6 columns]

# %% [markdown]
# C) Remove the columns 'year' and 'month' from the dataframe.
#
# data.drop(['month', 'year'], axis = 2)

# %%
data.drop(['month', 'year'], axis = 1, inplace = True)

# %% [markdown]
# D ) Show all the records where 'No of Crimes' is 0. And, how many such records are there ?

# %%
len(data[data.no_of_crimes == 0 ])
# Out:
# 104

# %% [markdown]
# E) What is maximum & minimum 'average_price' per year in england?

# %%
data1 = data[data.area == 'england']
data1
# Out:
#             date  month     area  average_price       code  houses_sold  \
# 13248 1995-01-01      1  england          53203  E92000001      47639.0
# 13249 1995-02-01      2  england          53096  E92000001      47880.0
# 13250 1995-03-01      3  england          53201  E92000001      67025.0
# 13251 1995-04-01      4  england          53591  E92000001      56925.0
# 13252 1995-05-01      5  england          53678  E92000001      64192.0
# ...          ...    ...      ...            ...        ...          ...
# 13544 2019-09-01      9  england         249942  E92000001      64605.0
# 13545 2019-10-01     10  england         249376  E92000001      68677.0
# 13546 2019-11-01     11  england         248515  E92000001      67814.0
# 13547 2019-12-01     12  england         250410  E92000001          NaN
# 13548 2020-01-01      1  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...             ...   ...
# 13544           NaN  2019
# 13545           NaN  2019
# 13546           NaN  2019
# 13547           NaN  2019
# 13548           NaN  2020
#
# [301 rows x 8 columns]

# %%
data1.groupby('year').average_price.max() #.min()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %% [markdown]
# F) what is the maxium & min no of crimes recorded per year

# %%
data.groupby('year').no_of_crimes.max().sort_values(ascending = False)
# Out:
# year
# 2019    7461.0
# 2002    7076.0
# 2001    7002.0
# 2018    6743.0
# 2020    6405.0
# 2004    6290.0
# 2003    6149.0
# 2011    6106.0
# 2012    5972.0
# 2010    5766.0
# 2005    5753.0
# 2009    5703.0
# 2008    5578.0
# 2007    5509.0
# 2006    5467.0
# 2017    5198.0
# 2013    5047.0
# 2016    4903.0
# 2015    4561.0
# 2014    4478.0
# 1995       NaN
# 1996       NaN
# 1997       NaN
# 1998       NaN
# 1999       NaN
# 2000       NaN
# Name: no_of_crimes, dtype: float64

# %% [markdown]
# G) Show the total count of records of each area, where average price is less than 100000

# %%
data[data.average_price < 1000000].area.value_counts()
# Out:
# area
# enfield                   302
# tower hamlets             302
# hackney                   302
# south east                302
# city of london            301
# barking and dagenham      301
# barnet                    301
# bexley                    301
# brent                     301
# bromley                   301
# camden                    301
# croydon                   301
# ealing                    301
# greenwich                 301
# hammersmith and fulham    301
# haringey                  301
# harrow                    301
# havering                  301
# hillingdon                301
# hounslow                  301
# islington                 301
# kingston upon thames      301
# lambeth                   301
# lewisham                  301
# merton                    301
# newham                    301
# redbridge                 301
# richmond upon thames      301
# southwark                 301
# sutton                    301
# waltham forest            301
# wandsworth                301
# inner london              301
# outer london              301
# north east                301
# north west                301
# yorks and the humber      301
# east midlands             301
# west midlands             301
# east of england           301
# london                    301
# south west                301
# england                   301
# westminster               273
# kensington and chelsea    209
# Name: count, dtype: int64
